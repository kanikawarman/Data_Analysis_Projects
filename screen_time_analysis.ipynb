# %% [markdown]
# # Screen Time Analysis

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/kaggle/input/analyzing-screen-time/Screentime - App Details.csv")

# %% [markdown]
# # EDA

# %%
df.head() #top 5 data
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
df.tail() #last 5 data
# Out:
#           Date  Usage  Notifications  Times opened       App
# 49  09/17/2022    212            212           120  Whatsapp
# 50  09/18/2022    244            303           132  Whatsapp
# 51  09/19/2022     77            169           105  Whatsapp
# 52  09/20/2022     58            190            78  Whatsapp
# 53  09/21/2022     89            262            68  Whatsapp

# %%
df.sample(5) #It brings random data
# Out:
#           Date  Usage  Notifications  Times opened        App
# 39  09/07/2022    160            212            83   Whatsapp
# 20  09/15/2022      2             15             4  Instagram
# 33  09/01/2022     23             99            47   Whatsapp
# 47  09/15/2022     50            181            58   Whatsapp
# 36  09/04/2022      6             38            33   Whatsapp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           54 non-null     object
#  1   Usage          54 non-null     int64
#  2   Notifications  54 non-null     int64
#  3   Times opened   54 non-null     int64
#  4   App            54 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df.isnull().sum() #Specifies the empty column
# Out:
# Date             0
# Usage            0
# Notifications    0
# Times opened     0
# App              0
# dtype: int64

# %%
df.corr()
# Out:
#                   Usage  Notifications  Times opened
# Usage          1.000000       0.774452      0.816409
# Notifications  0.774452       1.000000      0.882983
# Times opened   0.816409       0.882983      1.000000

# %%
plt.figure(figsize=(10,10)) #chart size
sns.heatmap(df.corr(),annot=True) #Corr graphic display
# Out:
# <AxesSubplot:>

# %%
df["App"].value_counts()
# Out:
# Instagram    27
# Whatsapp     27
# Name: App, dtype: int64

# %%
ax=sns.countplot(x=df["App"]) #
ax.bar_label(ax.containers[0]);

# %%
df.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %%
df.columns # column names
# Out:
# Index(['Date', 'Usage', 'Notifications', 'Times opened', 'App'], dtype='object')

# %%
df.shape #how many rows, how many columns
# Out:
# (54, 5)

# %% [markdown]
# # Apps Usage

# %%
px.bar(df, x="Date", y="Usage", color="App", title="Usage")
# Out:
# <div>                            <div id="cae78f95-2fea-4049-9b4a-eaf6891a2baf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cae78f95-2fea-4049-9b4a-eaf6891a2baf")) {                    Plotly.newPlot(                        "cae78f95-2fea-4049-9b4a-eaf6891a2baf",                        [{"alignmentgroup":"True","hovertemplate":"App=Instagram<br>Date=%{x}<br>Usage=%{y}<extra></extra>","legendgroup":"Instagram","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Instagram","offsetgroup":"Instagram","orientation":"v","showlegend":true,"textposition":"auto","x":["08/26/2022","08/27/2022","08/28/2022","08/29/2022","08/30/2022","08/31/2022","09/01/2022","09/02/2022","09/03/2022","09/04/2022","09/05/2022","09/06/2022","09/07/2022","09/08/2022",
# ...

# %% [markdown]
# # Number of notifications from apps

# %%
px.bar(df, x="Date", y="Notifications", color="App", title="Notifications")
# Out:
# <div>                            <div id="50cd52a7-1e81-4a82-9401-f4ce4c2aeac8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50cd52a7-1e81-4a82-9401-f4ce4c2aeac8")) {                    Plotly.newPlot(                        "50cd52a7-1e81-4a82-9401-f4ce4c2aeac8",                        [{"alignmentgroup":"True","hovertemplate":"App=Instagram<br>Date=%{x}<br>Notifications=%{y}<extra></extra>","legendgroup":"Instagram","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Instagram","offsetgroup":"Instagram","orientation":"v","showlegend":true,"textposition":"auto","x":["08/26/2022","08/27/2022","08/28/2022","08/29/2022","08/30/2022","08/31/2022","09/01/2022","09/02/2022","09/03/2022","09/04/2022","09/05/2022","09/06/2022","09/07/2022","09/0
# ...

# %% [markdown]
# # Number of apps opened

# %%
px.bar(df, x="Date", y="Times opened", color="App", title="Times Opened")
# Out:
# <div>                            <div id="e4f9bb8f-006b-4ad6-a263-2e80c08049d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4f9bb8f-006b-4ad6-a263-2e80c08049d7")) {                    Plotly.newPlot(                        "e4f9bb8f-006b-4ad6-a263-2e80c08049d7",                        [{"alignmentgroup":"True","hovertemplate":"App=Instagram<br>Date=%{x}<br>Times opened=%{y}<extra></extra>","legendgroup":"Instagram","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Instagram","offsetgroup":"Instagram","orientation":"v","showlegend":true,"textposition":"auto","x":["08/26/2022","08/27/2022","08/28/2022","08/29/2022","08/30/2022","08/31/2022","09/01/2022","09/02/2022","09/03/2022","09/04/2022","09/05/2022","09/06/2022","09/07/2022","09/08
# ...

# %% [markdown]
# # The relationship between the number of notifications and the amount of use

# %%
px.scatter(df, x="Notifications", y="Usage", size="Notifications", trendline="ols", title="Relationship Between Number of Notifications and Usage")
# Out:
# <div>                            <div id="d9c59270-da36-49ed-95b7-855b71cfc70e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9c59270-da36-49ed-95b7-855b71cfc70e")) {                    Plotly.newPlot(                        "d9c59270-da36-49ed-95b7-855b71cfc70e",                        [{"hovertemplate":"Notifications=%{marker.size}<br>Usage=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[70,43,231,35,19,25,23,28,15,29,24,34,23,48,68,71,180,99,45,10,15,13,9,8,8,11,12,209,111,183,157,246,169,99,144,80,38,218,205,212,217,405,166,173,290,153,192,181,176,212,303,169,190,262],"sizemode":"area","sizeref":1.0125,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[70,43,231,35,19,25,23,28,15,
# ...

# %% [markdown]
# # There is a linear relationship between the number of notifications and the amount of usage. This means that more notifications result in more use of smartphones.
